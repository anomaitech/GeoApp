# %% [markdown]
# <a href="https://colab.research.google.com/github/anomaitech/GeoApp/blob/main/Efficient_transportation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
counties=gpd.read_file('/content/drive/MyDrive/BYU/Geospatial software development/Counties_UTAarea.shp')

# %%
crashes=gpd.read_file('/content/drive/MyDrive/BYU/Geospatial software development/PedestrianCrashesUTAarea.shp')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bas_stop=gpd.read_file('/content/drive/MyDrive/BYU/Geospatial software development/UTA_STOPS.shp')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
intersection=gpd.read_file('/content/drive/MyDrive/BYU/Geospatial software development/IntersectionDensityUTAarea')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# <ipython-input-22-d0caa03e6979> in <cell line: 0>()
# ----> 1 intersection=gpd.read_file('/content/drive/MyDrive/BYU/Geospatial software development/IntersectionDensityUTAarea')
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     292
#     293     if engine == "pyogrio":
# --> 294         return _read_file_pyogrio(
#     295             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296         )
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     545         kwargs["columns"] = kwargs.pop("include_fields")
#     546
# --> 547     return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#     548
#     549
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/geopandas.py in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     263         # as numpy does not directly support timezones.
#     264         kwargs["datetime_as_string"] = True
# --> 265     result = read_func(
#     266         path_or_buffer,
#     267         layer=layer,
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#     196     dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
#     197
# --> 198     return ogr_read(
#     199         get_vsi_path_or_buffer(path_or_buffer),
#     200         layer=layer,
#
# pyogrio/_io.pyx in pyogrio._io.ogr_read()
#
# pyogrio/_io.pyx in pyogrio._io.ogr_open()
#
# DataSourceError: /content/drive/MyDrive/BYU/Geospatial software development/IntersectionDensityUTAarea: No such file or directory

# %%
# prompt: use gee map to plot counties

import ee
import geemap

ee.Authenticate()

# Initialize the library.
ee.Initialize(project='ee-anomaitech')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import geemap

# Convert GeoDataFrame to Earth Engine FeatureCollection
counties_ee = geemap.geopandas_to_ee(counties)
crashes_ee = geemap.geopandas_to_ee(crashes)
bas_stop_ee = geemap.geopandas_to_ee(bas_stop)

# Create a map centered on the data
Map = geemap.Map()
Map.centerObject(counties_ee, 8)

# Define style dictionaries for each layer
county_style = {
    'color': 'blue',        # outline color
    'fillColor': '00000000', # transparent fill
    'width': 2
}

crash_style = {
    'color': 'red',         # outline color
    'fillColor': 'red',     # fill color
    'width': 1
}

stop_style = {
    'color': 'green',       # outline color
    'fillColor': 'green',   # fill color
    'width': 1
}

# Add styled layers to the map
Map.addLayer(counties_ee.style(**county_style), {}, 'Counties')
Map.addLayer(crashes_ee.style(**crash_style), {}, 'Crashes')
Map.addLayer(bas_stop_ee.style(**stop_style), {}, 'Stops')

# Display the map
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40.872158529156636, -112.76756170518492], controls=(WidgetControl(options=['position', 'transparen…

# %%
crashes.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    FID_projec   Crash_ID           Crash_Date  Year Full_Route  Milepoint  \
# 0        3689  823825887  05/06/2023 04:30 PM  2023       None      0.000
# 1        1517  820654296  10/30/2020 09:31 PM  2020      0006P    196.006
# 2        1056  820617830  03/21/2020 01:21 PM  2020      0006P    160.302
# 3        1676  821667762  01/25/2021 05:20 PM  2021      0006P    159.599
# 4        1635  821664955  01/06/2021 06:00 PM  2021       None      0.000
#
#                  Crash_Seve                     Manner_of_  \
# 0  Suspected Serious Injury  Not Applicable/Single Vehicle
# 1    Suspected Minor Injury                 Parked Vehicle
# 2           Possible injury  Not Applicable/Single Vehicle
# 3    Suspected Minor Injury  Not Applicable/Single Vehicle
# 4  Suspected Serious Injury  Not Applicable/Single Vehicle
#
#                     Roadway_Ju          Light_Cond  ...  NAME  FIPS  \
# 0                       Other*            Daylight  ...  UTAH  49.0
# 1  No Special Feature/Junction  Dark - Not Lighted  ...  UTAH  49.0
# 2  No Special Feature/Junction            Daylight  ...  UTAH  49.0
# 3  No Special Feature/Junction            Daylight  ...  UTAH  49.0
# 4  No Special Feature/Junction  Dark - Not Lighted  ...  UTAH  49.0
#
#    STATEPLANE POP_LASTCE POP_CURRES                              GlobalID  \
# 0     Central     659399     702434  8df99710-dcb1-4c52-8ead-e9555c83618f
# 1     Central     659399     702434  8df99710-dcb1-4c52-8ead-e9555c83618f
# 2     Central     659399     702434  8df99710-dcb1-4c52-8ead-e9555c83618f
# 3     Central     659399     702434  8df99710-dcb1-4c52-8ead-e9555c83618f
# 4     Central     659399     702434  8df99710-dcb1-4c52-8ead-e9555c83618f
#
#   FIPS_STR COLOR4     Shape_Leng                        geometry
# 0    49049      3  629812.249713   POINT (430082.877 4422368.89)
# 1    49049      3  629812.249713  POINT (472494.411 4424120.572)
# 2    49049      3  629812.249713  POINT (433620.655 4425339.187)
# 3    49049      3  629812.249713  POINT (432490.142 4425351.179)
# 4    49049      3  629812.249713  POINT (432773.394 4425807.931)
#
# [5 rows x 48 columns]

# %%
bas_stop.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    fid_  stopabbr                   stopname             city     county  \
# 0  5251  TX136036        Meadowbrook Station  South Salt Lake  Salt Lake
# 1   195    101369            9800 S @ 2567 E            Sandy  Salt Lake
# 2  5253  TX136048       Murray North Station           Murray  Salt Lake
# 3  5098  FR101393  Salt Lake Central Station   Salt Lake City  Salt Lake
# 4  5108  FR601085                Roy Station              Roy      Weber
#
#   stopabbr_j  uta_stopid   latitude   longitude  avgboard  avgalight  \
# 0   TX136036      136036  40.687328 -111.896553       396        389
# 1     101369      101369  40.573207 -111.818319         0          0
# 2   TX136048      136048  40.676454 -111.894079       292        295
# 3   FR101393      101393  40.762340 -111.909052      1038       1256
# 4   FR601085      601085  41.188757 -112.039378       373        360
#
#                  route         mode zipcode    avgboard2   avgalight2  \
# 0  Blue Line, Red Line         TRAX   84115   396.216770   388.715378
# 1                  F94     Flex Bus   84092     0.000000     0.000000
# 2  Blue Line, Red Line         TRAX   84107   292.476129   295.193813
# 3          FrontRunner  FrontRunner   84101  1037.743335  1256.090870
# 4          FrontRunner  FrontRunner   84067   373.416981   360.031556
#
#                       geometry
# 0  POINT (-111.89655 40.68733)
# 1  POINT (-111.81832 40.57321)
# 2  POINT (-111.89408 40.67645)
# 3  POINT (-111.90905 40.76234)
# 4  POINT (-112.03938 41.18876)
